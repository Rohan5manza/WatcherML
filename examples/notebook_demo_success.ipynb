# %%
# %load_ext watcherml

# %%
# %watcher project notebook-demo

# %%
import watcherml as watcher

# %%
run = watcher.init(config={'model': 'resnet50', 'lr': 2e-4, 'batch_size': 16})

# %%
run.log_metric('val_accuracy', 0.80, step=1)

# %%
run.finish()
