# %%
# %load_ext watcherml

# %%
# %watcher project notebook-demo

# %%
import watcherml as watcher

# %%
run = watcher.init(config={'model': 'resnet50', 'lr': 1e-3, 'batch_size': 32})

# %%
run.log_metric('val_accuracy', 0.4, step=1)

# %%
raise RuntimeError('CUDA out of memory. Tried to allocate 2.10 GiB (GPU 0; 11.00 GiB total capacity)')
